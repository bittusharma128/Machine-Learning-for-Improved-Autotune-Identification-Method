# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Analysis Without Noise

# %%
data = pd.read_csv('projectfilefinal.csv')

# %%
data
# Out:
#      Relay Height  Gain  Delay  Time Constant  Actual A   Noisy A  \
# 0               1     1      2            1.0     0.8540   0.8640
# 1               1     1      2            1.5     0.7362   0.7298
# 2               1     1      2            2.0     0.6316   0.6310
# 3               1     1      2            2.5     0.5482   0.5460
# 4               1     1      2            3.0     0.4866   0.4788
# ..            ...   ...    ...            ...        ...      ...
# 580             1     9      8           18.0     3.2270   3.1930
# 581             1     9      8           18.5     3.1600   3.1230
# 582             1     9      8           19.0     3.0890   3.0620
# 583             1     9      8           19.5     3.0270   3.0050
# 584             1     9      8           20.0     2.9660   2.9300
#
#      Time period  Estimated T  Estimated D  Estimated T(N)  Estimated D(N)
# 0          5.248     0.923701     1.926023        0.904174        1.934910
# ...

# %%
y1 = data['Time Constant']

# %%
y2 = data['Delay']

# %%
data.drop(['Time Constant'], axis = 1, inplace = True)

# %%
data.drop(['Delay'], axis = 1, inplace = True)

# %%
data.drop(['Actual A '], axis = 1, inplace = True)

# %%
data.drop(['Estimated T'], axis = 1, inplace = True)

# %%
data.drop(['Estimated D'], axis = 1, inplace = True)

# %%
data
# Out:
#      Relay Height  Gain  Noisy A  Time period  Estimated T(N)  Estimated D(N)
# 0               1     1   0.8640        5.248        0.904174        1.934910
# 1               1     1   0.7298        5.656        1.286998        1.963413
# 2               1     1   0.6310        5.960        1.662555        1.981794
# 3               1     1   0.5460        6.194        2.076877        1.985357
# 4               1     1   0.4788        6.379        2.501778        1.986110
# ..            ...   ...      ...          ...             ...             ...
# 580             1     9   3.1930       27.038       14.832865        7.974445
# 581             1     9   3.1230       27.133       15.246368        7.975021
# 582             1     9   3.0620       27.225       15.627019        7.978108
# 583             1     9   3.0050       27.313       15.997543        7.981473
# 584             1     9   2.9300       27.398       16.488022        7.976764
#
# [585 rows x 6 columns]

# %%
X = data

# %%
y1
# Out:
# 0       1.0
# 1       1.5
# 2       2.0
# 3       2.5
# 4       3.0
#        ...
# 580    18.0
# 581    18.5
# 582    19.0
# 583    19.5
# 584    20.0
# Name: Time Constant, Length: 585, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size = 0.2, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor1 = DecisionTreeRegressor(random_state = 2)
regressor1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=2)

# %%
y_pred = regressor1.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9406138483187403

# %%
 regressor1.score(X_train,y_train)
# Out:
# 1.0

# %%
from yellowbrick.regressor import residuals_plot
from yellowbrick.regressor import prediction_error

# %%
from yellowbrick.regressor import PredictionError

# %%
visualizer = PredictionError(regressor1,xlabel = '$y_pred$',ylabel='$y_test$')

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for DecisionTreeRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
print(prediction_error(regressor1, X_train, y_train, X_test, y_test))
# Out:
# PredictionError(ax=<AxesSubplot:title={'center':'Prediction Error for DecisionTreeRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>,
#                 estimator=DecisionTreeRegressor(random_state=2))

# %%
print("\nResiduals Plot")
print(residuals_plot(regressor1, X_train, y_train, X_test, y_test))
# Out:
# Residuals Plot
# ResidualsPlot(ax=<AxesSubplot:title={'center':'Residuals for DecisionTreeRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>,
#               estimator=DecisionTreeRegressor(random_state=2), line_color=None,
#               test_alpha=None, test_color=None, train_alpha=None,
#               train_color=None)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '

# %%
ym = X_test['Measured T(N)']

# %%
y_pred = regressor1.predict(X_test)

# %%
 ym = ym.to_numpy()

# %%
 y_test = y_test.to_numpy()

# %%
t = [i for i in range(117)]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Comparison between y_measured,y_predicted and y_actual)')

ax1.plot(t, y_pred,'b',y_test, 'r.-')
ax1.set_ylabel('y_predicted and y_actual')

ax2.plot(t, ym,'r-',y_test, 'y.-')
ax2.set_xlabel('Points')
ax2.set_ylabel('y_measured and y_actual')

plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size = 0.2, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor2 = DecisionTreeRegressor(random_state = 2)
regressor2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=2)

# %%
y_pred = regressor2.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9977436649053111

# %%
 regressor2.score(X_train,y_train)
# Out:
# 1.0

# %%
 regressor2.score(X_test,y_test)
# Out:
# 0.9977436649053111

# %%
from numpy import asarray

# %%
y_pre = regressor2.predict([[1,4,1.869,14.434,5.823,4.47]]) # T = 7, D = 4.5, calculated T = 5.724, D = 4.4851
y_pre
# Out:
# array([5.])

# %%
xt = asarray([[1,4,1.869,14.434,5.823,4.47]]) 
regressor3.predict(xt)
# Out:
# array([4.59113602])

# %%
y_pre = regressor3.predict([[1,3.4,1.735,20.47,7.447,6.46]]) # T = 9, D = 6.5, calculated T = 7.447, D = 6.46
y_pre
# Out:
# array([6.4923766])

# %%
xt = asarray([[1,3.4,1.735,20.47,7.447,6.46]]) 
regressor3.predict(xt)
# Out:
# array([6.4923766])

# %%
y_pre = regressor3.predict([[1,6.3,4.759,8.3,1.792,2.91]]) # T = 2, D = 3, calculated T = 1.792, D = 2.91
y_pre
# Out:
# array([3.06319141])

# %%
xt = asarray([[1,6.3,4.759,8.3,1.792,2.91]]) 
regressor3.predict(xt)
# Out:
# array([3.06319141])

# %%
y_pre = regressor3.predict([[1,3,1.159,11.645,5.82,3.482]]) # T = 7, D = 3.5 , calculated T = 5.7, D = 3.493
y_pre
# Out:
# array([3.58522014])

# %%
xt = asarray([[1,3,1.159,11.645,5.82,3.482]]) 
regressor2.predict(xt)
# Out:
# array([4.])

# %%
y_pre = regressor2.predict([[1,6,2.255,6.655,3.428,1.98]]) # T = 4, D = 2, calculated T = 3.428, D = 1.98
y_pre
# Out:
# array([2.])

# %%
xt = asarray([[1,6,2.255,6.655,3.428,1.98]]) 
regressor3.predict(xt)
# Out:
# array([2.29156344])

# %%
y_pre = regressor3.predict([[1,8.1,3.379,17.057,7.828,5.170]]) # T = 9.4, D = 5.2, calculated T = 7.67, D = 5.187
y_pre
# Out:
# array([5.44543796])

# %%
y_pre = regressor3.predict([[1,3.4,1.735,20.47,7.447,6.46]]) # T = 9, D = 6.5, calculated T = 7.447, D = 6.46
y_pre
# Out:
# array([6.4923766])

# %%
y_pre = regressor3.predict([[1,6.3,4.759,8.3,1.792,2.91]]) # T = 2, D = 3, calculated T = 1.792, D = 2.91
y_pre
# Out:
# array([3.06319141])

# %%
y_pre = regressor3.predict([[1,3,1.159,11.645,5.82,3.482]]) # T = 7, D = 3.5 , calculated T = 5.7, D = 3.493
y_pre
# Out:
# array([3.58522014])

# %%
y_pre = regressor3.predict([[1,2,0.6548,6.85,4.097,1.99]]) # here T = 5, gain = 2 Delay = 2, calculated T = 4.09, D = 1.99
y_pre
# Out:
# array([2.09782141])

# %%
y_pre = regressor3.predict([[1,2,0.7808,9.992,4.936,2.99]])  # here T = 6 gain = 2 , Delay = 3, calculated T = 4.936, D = 2.99
y_pre
# Out:
# array([3.06791075])

# %%
# for delay

# %%
X = data

# %%
X
# Out:
#      Relay Height  Gain  Noisy A  Time period  Measured T(N)  Measured D(N)
# 0               1     1   0.8640        5.248       0.904174       1.934910
# 1               1     1   0.7298        5.656       1.286998       1.963413
# 2               1     1   0.6310        5.960       1.662555       1.981794
# 3               1     1   0.5460        6.194       2.076877       1.985357
# 4               1     1   0.4788        6.379       2.501778       1.986110
# ..            ...   ...      ...          ...            ...            ...
# 580             1     9   3.1930       27.038      14.832865       7.974445
# 581             1     9   3.1230       27.133      15.246368       7.975021
# 582             1     9   3.0620       27.225      15.627019       7.978108
# 583             1     9   3.0050       27.313      15.997543       7.981473
# 584             1     9   2.9300       27.398      16.488022       7.976764
#
# [585 rows x 6 columns]

# %%
y2
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 580    8
# 581    8
# 582    8
# 583    8
# 584    8
# Name: Delay, Length: 585, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
regressor3 = LinearRegression()
regressor3.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
 regressor3.score(X_test,y_test)
# Out:
# 0.9661770892969854

# %%
visualizer = PredictionError(regressor3,xlabel = '$y_pred$',ylabel='$y_test$')

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
print(prediction_error(regressor3, X_train, y_train, X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ca82f7ce1b23> in <module>
# ----> 1 print(prediction_error(regressor3, X_train, y_train, X_test, y_test))
#
# NameError: name 'prediction_error' is not defined

# %%
print("\nResiduals Plot")
print(residuals_plot(regressor3, X_train, y_train, X_test, y_test))
# Out:
# Residuals Plot
# ResidualsPlot(ax=<AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>,
#               estimator=LinearRegression(), line_color=None, test_alpha=None,
#               test_color=None, train_alpha=None, train_color=None)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '

# %%
ym = X_test['Measured D(N)']
y_pred = regressor3.predict(X_test)
ym = ym.to_numpy()
y_test = y_test.to_numpy()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Comparison between y_measured,y_predicted and y_actual)')

ax1.plot(t, y_pred,'b',y_test, 'r.-')
ax1.set_ylabel('y_predicted and y_actual')

ax2.plot(t, ym,'r-',y_test, 'y.-')
ax2.set_xlabel('Points')
ax2.set_ylabel('y_measured and y_actual')

plt.show()
